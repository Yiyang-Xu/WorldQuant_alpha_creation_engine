# %% [markdown]
# ### Import library

# %%
# pip install -r requirements.txt

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px
# Out:
# /Users/michaelxu/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ### Start session
# Enter credentials once - they will be saved to local folder and loaded each time

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_8X3RzkHN3tqcCwHkerhwGGyfR5Av

# %% [markdown]
# ### Create list of alpha expressions
# #### Step 1. Download datsets

# %%
datasets_df = hf.get_datasets(s) # by default we load all datasets USA TOP3000 delay 1
datasets_df.tail() # DataFrame.head() shows first 5 rows of the dataframe 
# print(len(datasets_df))
# Out:
#                id                          name  \
# 230  socialmedia5        Lexical Breakdown Data
# 231  socialmedia8  Social Media Data for Equity
# 232  socialmedia9    Social Media Activity Data
# 233         univ1              Universe Dataset
# 234         univ2              Universe Dataset
#
#                                            description     category  \
# 230  Sentiment scores derived from social media. So...  socialmedia
# 231  This is a sentiment dataset based on tweets or...  socialmedia
# 232  The dataset captures short-term estimated sent...  socialmedia
# 233                             No dataset description           pv
# 234                             No dataset description           pv
#
#                   subcategory region  delay universe  coverage turnover  \
# 230  socialmedia-social-media    USA      1  TOP3000    0.8590     None
# 231  socialmedia-social-media    USA      1  TOP3000    0.8585     None
# 232  socialmedia-social-media    USA      1  TOP3000    0.8787     None
# 233           pv-price-volume    USA      1  TOP3000    0.4480     None
# 234           pv-price-volume    USA      1  TOP3000       NaN     None
#
#      valueScore  userCount  alphaCount  fieldCount themes  \
# 230         1.0         52         491          12     []
# 231         1.0       1326        4009           2     []
# 232         3.0         10          28           4     []
# 233         3.0         14          41           4     []
# 234         2.0         11          36           1     []
#
#                                         researchPapers
# 230                                                 []
# 231  [{'title': 'Research Paper 65: News Diffusion ...
# 232                                                 []
# 233                                                 []
# 234                                                 []

# %%
# select needed datasets
selected_datasets_df = datasets_df[
    (datasets_df["delay"] == 1) &
    (datasets_df["coverage"] > 0.7) & (datasets_df["coverage"] <= 1) &
    (datasets_df["fieldCount"] > 0) & (datasets_df["fieldCount"] < 3000) &
    (datasets_df["region"] == 'USA') &
    (datasets_df["universe"] == 'TOP3000') &
    (datasets_df["userCount"] > 0) & (datasets_df["userCount"] < 500) &
    (datasets_df["valueScore"] > 1) & (datasets_df["valueScore"] < 20) &
    # datasets_df["name"].str.contains('news', case=False) &
    ((datasets_df["category"] == 'news') | (datasets_df["category"] == 'analyst'))
].sort_values(by=['valueScore'], ascending=False)
selected_datasets_df
# Out:
#             id                                        name  \
# 143     news85           News Sentiment Analysis using DNN
# 142     news84       Headline Sentiment Analysis using DNN
# 140     news77               Earnings Call Transcript Data
# 137     news59                       Corporate Events Data
# 136     news55                      Intermediate News Data
# 133     news51                        Aggregared News Data
# 130     news48                      Global Media News Data
# 125     news35                         Financial News Data
# 126     news36                         News Analytics Data
# 127     news38                    News Analytic Model Data
# 6    analyst21                 Indicators of Interest Data
# 141     news82                 Sentiment Analysis from DNN
# 135     news54                         Newa analystic data
# 132     news50                     Web News Analytics Data
# 129     news46                Relevant News Analytics Data
# 145     news92  Standardized Financial News Categorization
# 121     news22                       News Direct-feed Data
# 116     news17                             PR Edition Data
# 20   analyst69               Fundamental Analyst Estimates
# 13   analyst44                            Broker Estimates
# 128     news42                            US/AMR news data
# 124     news31                  News Analytics on Equities
# 123      news3               Dow Jones News Analytics Data
# 131      news5                    News Feed Analytics Data
# 119     news20             Web Sources News Sentiment Data
# 23    analyst9                 Analyst Estimate Daily Data
# 22    analyst8                 Analyst Estimate Daily Data
# 139      news7                    Real Time News Feed Data
# 10   analyst39        Analyst estimates & financial ratios
# 7    analyst27                 Analyst Estimate Daily Data
# 3    analyst16                         Real Time Estimates
#
#                                            description category  \
# 143  The dataset derived from applying neural netwo...     news
# 142  The dataset derived from applying neural netwo...     news
# 140  The dataset provieds a rich set of scores, tag...     news
# 137  The dataset is a collection of corporate event...     news
# 136  The dataset provides intermediate news data th...     news
# 133  The dataset provides aggregated news from diff...     news
# 130  The dataset provides news and information from...     news
# 125  The dataset provides NLP model output for arti...     news
# 126  The dataset consists of real-time news analyti...     news
# 127  The dataset provides datafields from news anal...     news
# 6    It is indications of interest (IOI) and trade ...  analyst
# 141  The dataset derived from applying neural netwo...     news
# 135  This dataset provides access to events & news ...     news
# 132  Analyze articles/news from leading publishers ...     news
# 129  The dataset includes rich structured informati...     news
# 145                             No dataset description     news
# 121                             worldwide news dataset     news
# 116  Dataset which analyzes news and information fr...     news
# 20   This dataset is a type of analyst dataset that...  analyst
# 13   This dataset integrates the detail estimates f...  analyst
# 128  This vendor provides an original content finan...     news
# 124  This dataset provides real-time news and its n...     news
# 123  The Sentiment Analysis Engine (SAE) is a softw...     news
# 131  This dataset provides news headlines with vari...     news
# 119  This dataset provides real-time structured sen...     news
# 23                             estimation from analyst  analyst
# 22   This dataset creates daily & history files for...  analyst
# 139  Combines various text new feeds from multiple ...     news
# 10   This dataset provides a lot of information on ...  analyst
# 7    Statistics data for analysts and estimators (t...  analyst
# 3    This dataset provides real-time access to the ...  analyst
#
#                         subcategory region  delay universe  coverage turnover  \
# 143             news-news-sentiment    USA      1  TOP3000    1.0000     None
# 142             news-news-sentiment    USA      1  TOP3000    1.0000     None
# 140             news-news-sentiment    USA      1  TOP3000    0.8079     None
# 137             news-news-sentiment    USA      1  TOP3000    1.0000     None
# 136                       news-news    USA      1  TOP3000    1.0000     None
# 133                       news-news    USA      1  TOP3000    0.9610     None
# 130             news-news-sentiment    USA      1  TOP3000    0.9678     None
# 125                       news-news    USA      1  TOP3000    1.0000     None
# 126             news-news-sentiment    USA      1  TOP3000    1.0000     None
# 127                       news-news    USA      1  TOP3000    0.8204     None
# 6           analyst-analyst-ratings    USA      1  TOP3000    1.0000     None
# 141             news-news-sentiment    USA      1  TOP3000    0.9906     None
# 135             news-news-sentiment    USA      1  TOP3000    0.8682     None
# 132             news-news-sentiment    USA      1  TOP3000    0.9133     None
# 129             news-news-sentiment    USA      1  TOP3000    0.9238     None
# 145             news-news-sentiment    USA      1  TOP3000    0.9047     None
# 121                       news-news    USA      1  TOP3000    0.8354     None
# 116                       news-news    USA      1  TOP3000    0.9217     None
# 20        analyst-analyst-estimates    USA      1  TOP3000    0.9528     None
# 13   analyst-crowdsourced-estimates    USA      1  TOP3000    0.7473     None
# 128                       news-news    USA      1  TOP3000    0.7688     None
# 124                       news-news    USA      1  TOP3000    0.8869     None
# 123             news-news-sentiment    USA      1  TOP3000    0.8883     None
# 131             news-news-sentiment    USA      1  TOP3000    0.9031     None
# 119             news-news-sentiment    USA      1  TOP3000    0.9314     None
# 23        analyst-analyst-estimates    USA      1  TOP3000    0.7432     None
# 22        analyst-analyst-estimates    USA      1  TOP3000    0.8098     None
# 139                       news-news    USA      1  TOP3000    0.7938     None
# 10                      analyst-esg    USA      1  TOP3000    0.9110     None
# 7         analyst-analyst-estimates    USA      1  TOP3000    0.8380     None
# 3    analyst-crowdsourced-estimates    USA      1  TOP3000    0.8252     None
#
#      valueScore  userCount  alphaCount  fieldCount themes  \
# 143         4.0          5           5           1     []
# 142         4.0          6           7           1     []
# 140         4.0         20          42          30     []
# 137         4.0          6          23           2     []
# 136         4.0          8          10           6     []
# 133         4.0          9          45          19     []
# 130         4.0         21          69          22     []
# 125         4.0          5           7           2     []
# 126         4.0         15          34          14     []
# 127         3.0         32          87          50     []
# 6           3.0         60         360          16     []
# 141         3.0          6          24           1     []
# 135         3.0         39         122          17     []
# 132         3.0         29         123          37     []
# 129         3.0         44         169          50     []
# 145         3.0         38         177          48     []
# 121         3.0         21          61           3     []
# 116         3.0         43         168          23     []
# 20          3.0        196        1466         610     []
# 13          3.0        202        2579         673     []
# 128         2.0         38         116           9     []
# 124         2.0         79        1418          31     []
# 123         2.0         73         333          19     []
# 131         2.0        109        1014          76     []
# 119         2.0         74         451          24     []
# 23          2.0         74         274          23     []
# 22          2.0         89         383           7     []
# 139         2.0        189        3495          61     []
# 10          2.0         94         689          37     []
# 7           2.0        106         786         100     []
# 3           2.0        122        2040         107     []
#
#                                         researchPapers
# 143                                                 []
# 142                                                 []
# 140                                                 []
# 137                                                 []
# 136                                                 []
# 133                                                 []
# 130                                                 []
# 125                                                 []
# 126                                                 []
# 127                                                 []
# 6                                                   []
# 141                                                 []
# 135                                                 []
# 132                                                 []
# 129                                                 []
# 145                                                 []
# 121  [{'title': 'Research Paper 25: The Momentum of...
# 116                                                 []
# 20                                                  []
# 13   [{'title': 'Research Paper 21: Non-GAAP Earnin...
# 128                                                 []
# 124                                                 []
# 123                                                 []
# 131                                                 []
# 119                                                 []
# 23                                                  []
# 22                                                  []
# 139  [{'title': 'Research Paper 25: The Momentum of...
# 10                                                  []
# 7                                                   []
# 3                                                   []

# %%
# 筛选潜在数据集
potential_datasets_df = datasets_df[
    (datasets_df["delay"] == 1) &
    (datasets_df["coverage"] > 0.8) & (datasets_df["coverage"] <= 1) &
    (datasets_df["fieldCount"] > 0) & (datasets_df["fieldCount"] < 1000) &
    (datasets_df["region"] == 'USA') &
    (datasets_df["universe"] == 'TOP3000') &
    (datasets_df["userCount"] > 0) & (datasets_df["userCount"] < 100) &
    (datasets_df["valueScore"] > 1) & (datasets_df["valueScore"] < 10)
]

# %% [markdown]
# For demonstration we are picking the dataset with the highest value score, this is not mandatory but definitely a recommended practice

# %% [markdown]
# #### Step 2. Select the needed datafields

# %%
dataset_id = selected_datasets_df.id.values.tolist()[0] # create a list of selected datasets ids, our list has only one element
dataset_id
# Out:
# 'news85'

# %%
datafields_df = hf.get_datafields(s, dataset_id=dataset_id) # download all fields of dataset news
datafields_df.head()
# Out:
#                 id              description  \
# 0  mws85_sentiment  Sentiment based on news
#
#                                              dataset category  \
# 0  {'id': 'news85', 'name': 'News Sentiment Analy...     news
#
#            subcategory region  delay universe    type  coverage turnover  \
# 0  news-news-sentiment    USA      1  TOP3000  VECTOR       1.0     None
#
#    userCount  alphaCount themes
# 0          5           5     []

# %% [markdown]
# #### Step 3. Create expression list, using selected datafields
# Here is an example: creating expressions that assign weights as per the time series skewness of vector average of the field value

# %%
expression_list = [f'ts_skewness(vec_avg({x}),120)' for x in datafields_df.id.values.tolist()] # create a list of alpha expressions ts_skewness(vec_avg({x}),120) where x is a datafield id

# %% [markdown]
# #### Step 4. Apply generate_alpha function to the expression list
# In generate alpha function you can specify region, universe, decay, delay and other simulation settings

# %%
#when you send multiple alphas for simulation, please make sure all alphas of a single list should have common settings
#alphas with different settings should be sent in a different list, for instance below list has all alphas with same settings

alpha_list = [ace.generate_alpha(x, region= "USA", universe = "TOP3000",) for x in expression_list]
print(len(alpha_list))
# alpha_list[0]
# Out:
# 1

# %% [markdown]
# This is an example - how alpha actually looks like when you send it to the platform.

# %% [markdown]
# ### Simulate alpha list, get simulation result
#
# simulate_alpha_list_multi will do a multi-simulation if list of alphas is greater than 10, which is the case here
#
# the returned object will contain simulation results for all alphas as a list

# %%
#alpha expressions are sliced to first 10 for demonstration purpose

result = ace.simulate_alpha_list_multi(s, alpha_list[:20])
# Out:
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|██████████| 1/1 [00:43<00:00, 43.39s/it]

# %%
#we received a list of 10 simulation results since we sent in alpha_list[:10]
len(result)
# Out:
# 1

# %% [markdown]
# __Accessing the result of the first alpha, let's take a look at all the keys of this dictionary__

# %%
result[0].keys()
# Out:
# dict_keys(['alpha_id', 'simulate_data', 'is_stats', 'pnl', 'stats', 'is_tests', 'train', 'test'])

# %%
#is_stats key will return a dataframe storing IS summary results

result[0]['is_stats']
# Out:
#       pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
# 0 -523426  20000000       1395        1645    0.0812  -0.0052     0.115
#
#      margin  fitness  sharpe   startDate alpha_id
# 0 -0.000129    -0.04   -0.19  2012-01-22  LpPoWne

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#       pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0 -523426   20000000        1395         1645    0.0812  -0.0052     0.115
#
#      margin  fitness  sharpe  ...                                 expression  \
# 0 -0.000129    -0.04   -0.19  ...  ts_skewness(vec_avg(mws84_sentiment),120)
#
#   concentrated_weight high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0                PASS          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_competition matches_themes
# 0                    PASS         PASS             WARNING        WARNING
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Visualise pnl of an alpha

# %%
alpha_pnl = ace.get_alpha_pnl(s, result_st1['alpha_id'][0])
px.line(x = alpha_pnl.index, y = alpha_pnl.Pnl, title=f'<b>alpha_id={hf.make_clickable_alpha_id(alpha_pnl.alpha_id[0])}</b>')\
    .update_layout(xaxis_title="Date", yaxis_title="Pnl", title_x=0.5)
# Out:
# /var/folders/2h/657ql8s954s35xlylnvyhmrw0000gn/T/ipykernel_78549/3175675261.py:2: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %% [markdown]
# ### Select prospect alphas, that are worth improving (in your opinion)
# In this example we are selecting alphas with high fitness, to resimulate it with improved logic

# %%
prospect_alphas = result_st1.loc[lambda x: x.fitness>0.2]['expression'].values
prospect_alphas
# Out:
# array(['ts_skewness(vec_avg(mws36_novelty_oldest_span),120)',
#        'ts_skewness(vec_avg(mws36_relevance),120)',
#        'ts_skewness(vec_avg(mws36_sentiment_phrase_positive),120)',
#        'ts_skewness(vec_avg(mws36_sentiment_positive_confidence),120)',
#        'ts_skewness(vec_avg(mws36_novelty),120)',
#        'ts_skewness(vec_avg(mws36_novelty_newest_span),120)'],
#       dtype=object)

# %% [markdown]
# ### Change the expression - what would you do to improve alpha's results?
# <br>Use your own logic to improve the alphas.</br>
# <br>Here we will apply **group_rank** to overcome poor weight distribution.</br>

# %%
new_expression_list = ['group_rank(' + a + ',sector)' for a in prospect_alphas]
new_expression_list
# Out:
# ['group_rank(ts_skewness(vec_avg(mws36_novelty_oldest_span),120),sector)',
#  'group_rank(ts_skewness(vec_avg(mws36_relevance),120),sector)',
#  'group_rank(ts_skewness(vec_avg(mws36_sentiment_phrase_positive),120),sector)',
#  'group_rank(ts_skewness(vec_avg(mws36_sentiment_positive_confidence),120),sector)',
#  'group_rank(ts_skewness(vec_avg(mws36_novelty),120),sector)',
#  'group_rank(ts_skewness(vec_avg(mws36_novelty_newest_span),120),sector)']

# %%
#generating new simulation data for new expressions

new_alpha_list = [ace.generate_alpha(x, region= "USA", universe = "TOP3000",) for x in new_expression_list]

# %% [markdown]
# ### Re-simulation

# %%
new_result = ace.simulate_alpha_list_multi(s, new_alpha_list)
# Out:
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|██████████| 6/6 [01:56<00:00, 19.47s/it]

# %%
result_st2 = hf.prettify_result(new_result, clickable_alpha_id=False)
result_st2
# Out:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   894783   20000000        1037         1036    0.0928   0.0223    0.0544
# 1  1934904   20000000        1505         1505    0.0745   0.0194    0.0301
# 2  1862981   20000000        1305         1296    0.0749   0.0187    0.0637
# 3  1980504   20000000        1305         1296    0.0743   0.0198    0.0839
# 4  1472345   20000000        1546         1543    0.0658   0.0147    0.0438
# 5   725887   20000000        1543         1542    0.0664   0.0073    0.0831
#
#      margin  fitness  sharpe  ...  \
# 0  0.000480     0.32    0.75  ...
# 1  0.000520     0.31    0.78  ...
# 2  0.000498     0.27    0.70  ...
# 3  0.000534     0.27    0.68  ...
# 4  0.000448     0.20    0.57  ...
# 5  0.000219     0.07    0.29  ...
#
#                                           expression concentrated_weight  \
# 0  group_rank(ts_skewness(vec_avg(mws36_relevance...                FAIL
# 1  group_rank(ts_skewness(vec_avg(mws36_novelty),...                PASS
# 2  group_rank(ts_skewness(vec_avg(mws36_novelty_o...                PASS
# 3  group_rank(ts_skewness(vec_avg(mws36_novelty_n...                PASS
# 4  group_rank(ts_skewness(vec_avg(mws36_sentiment...                PASS
# 5  group_rank(ts_skewness(vec_avg(mws36_sentiment...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
# 1          PASS             FAIL        FAIL       FAIL
# 2          PASS             FAIL        FAIL       FAIL
# 3          PASS             FAIL        FAIL       FAIL
# 4          PASS             FAIL        FAIL       FAIL
# 5          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_competition matches_themes
# 0                    PASS         PASS             WARNING        WARNING
# 1                    PASS         PASS             WARNING        WARNING
# 2                    PASS         PASS             WARNING        WARNING
# 3                    PASS         PASS             WARNING        WARNING
# 4                    PASS         PASS             WARNING        WARNING
# 5                    FAIL         PASS             WARNING        WARNING
#
# [6 rows x 22 columns]

# %% [markdown]
# #### Compare alphas stats before and after changes:

# %%
## We will join before and after dataframes by field

result_st1['field'] = result_st1['expression'].apply(lambda st: st[st.find("(vec_avg(")+1:st.find(",")]).copy()
result_st2['field'] = result_st2['expression'].apply(lambda st: st[st.find("(vec_avg(")+1:st.find(",")]).copy()

# %%
#merging results before and after improvement

compare_results = pd.merge(result_st1, result_st2, on='field', suffixes=('_before', '_after'))

# %%
#selecting column list returned by merging the two alpha results

col_list = ['fitness_before', 'fitness_after','sharpe_before', 'sharpe_after', 'alpha_id_before', 'alpha_id_after',
                 'expression_before', 'expression_after']

compare_results[col_list]\
    .style.format({'alpha_id_before': hf.make_clickable_alpha_id, 'alpha_id_after': hf.make_clickable_alpha_id})
# Out:
# <style type="text/css">
# </style>
# <table id="T_19dbc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19dbc_level0_col0" class="col_heading level0 col0" >fitness_before</th>
#       <th id="T_19dbc_level0_col1" class="col_heading level0 col1" >fitness_after</th>
#       <th id="T_19dbc_level0_col2" class="col_heading level0 col2" >sharpe_before</th>
#       <th id="T_19dbc_level0_col3" class="col_heading level0 col3" >sharpe_after</th>
#       <th id="T_19dbc_level0_col4" class="col_heading level0 col4" >alpha_id_before</th>
#       <th id="T_19dbc_level0_col5" class="col_heading level0 col5" >alpha_id_after</th>
#       <th id="T_19dbc_level0_col6" class="col_heading level0 col6" >expression_before</th>
#       <th id="T_19dbc_level0_col7" class="col_heading level0 col7" >expression_after</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19dbc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19dbc_row0_col0" class="data row0 col0" >0.340000</td>
#       <td id="T_19dbc_row0_col1" class="data row0 col1" >0.270000</td>
#       <td id="T_19dbc_row0_col2" class="data row0 col2" >0.400000</td>
#       <td id="T_19dbc_row0_col3" class="data row0 col3" >0.700000</td>
#       <td id="T_19dbc_row0_col4" class="data row0 col4" ><a href="https://platform.worldquantbrain.com/alpha/ng155pa">ng155pa</a></td>
#       <td id="T_19dbc_row0_col5" class="data row0 col5" ><a href="https://platform.worldquantbrain.com/alpha/8zmx0AV">8zmx0AV</a></td>
#       <td id="T_19dbc_row0_col6" class="data row0 col6" >ts_skewness(vec_avg(mws36_novelty_oldest_span),120)</td>
#       <td id="T_19dbc_row0_col7" class="data row0 col7" >group_rank(ts_skewness(vec_avg(mws36_novelty_oldest_span),120),sector)</td>
#     </tr>
#     <tr>
#       <th id="T_19dbc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19dbc_row1_col0" class="data row1 col0" >0.330000</td>
#       <td id="T_19dbc_row1_col1" class="data row1 col1" >0.320000</td>
#       <td id="T_19dbc_row1_col2" class="data row1 col2" >0.760000</td>
#       <td id="T_19dbc_row1_col3" class="data row1 col3" >0.750000</td>
#       <td id="T_19dbc_row1_col4" class="data row1 col4" ><a href="https://platform.worldquantbrain.com/alpha/Vpvbb1w">Vpvbb1w</a></td>
#       <td id="T_19dbc_row1_col5" class="data row1 col5" ><a href="https://platform.worldquantbrain.com/alpha/Gwq52J5">Gwq52J5</a></td>
#       <td id="T_19dbc_row1_col6" class="data row1 col6" >ts_skewness(vec_avg(mws36_relevance),120)</td>
#       <td id="T_19dbc_row1_col7" class="data row1 col7" >group_rank(ts_skewness(vec_avg(mws36_relevance),120),sector)</td>
#     </tr>
#     <tr>
#       <th id="T_19dbc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_19dbc_row2_col0" class="data row2 col0" >0.300000</td>
#       <td id="T_19dbc_row2_col1" class="data row2 col1" >0.070000</td>
#       <td id="T_19dbc_row2_col2" class="data row2 col2" >0.360000</td>
#       <td id="T_19dbc_row2_col3" class="data row2 col3" >0.290000</td>
#       <td id="T_19dbc_row2_col4" class="data row2 col4" ><a href="https://platform.worldquantbrain.com/alpha/p6qeemb">p6qeemb</a></td>
#       <td id="T_19dbc_row2_col5" class="data row2 col5" ><a href="https://platform.worldquantbrain.com/alpha/m8PWG26">m8PWG26</a></td>
#       <td id="T_19dbc_row2_col6" class="data row2 col6" >ts_skewness(vec_avg(mws36_sentiment_phrase_positive),120)</td>
#       <td id="T_19dbc_row2_col7" class="data row2 col7" >group_rank(ts_skewness(vec_avg(mws36_sentiment_phrase_positive),120),sector)</td>
#     </tr>
#     <tr>
#       <th id="T_19dbc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_19dbc_row3_col0" class="data row3 col0" >0.260000</td>
#       <td id="T_19dbc_row3_col1" class="data row3 col1" >0.200000</td>
#       <td id="T_19dbc_row3_col2" class="data row3 col2" >0.670000</td>
#       <td id="T_19dbc_row3_col3" class="data row3 col3" >0.570000</td>
#       <td id="T_19dbc_row3_col4" class="data row3 col4" ><a href="https://platform.worldquantbrain.com/alpha/LpPYYj6">LpPYYj6</a></td>
#       <td id="T_19dbc_row3_col5" class="data row3 col5" ><a href="https://platform.worldquantbrain.com/alpha/Gwq52k0">Gwq52k0</a></td>
#       <td id="T_19dbc_row3_col6" class="data row3 col6" >ts_skewness(vec_avg(mws36_sentiment_positive_confidence),120)</td>
#       <td id="T_19dbc_row3_col7" class="data row3 col7" >group_rank(ts_skewness(vec_avg(mws36_sentiment_positive_confidence),120),sector)</td>
#     </tr>
#     <tr>
#       <th id="T_19dbc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_19dbc_row4_col0" class="data row4 col0" >0.250000</td>
#       <td id="T_19dbc_row4_col1" class="data row4 col1" >0.310000</td>
#       <td id="T_19dbc_row4_col2" class="data row4 col2" >0.660000</td>
#       <td id="T_19dbc_row4_col3" class="data row4 col3" >0.780000</td>
#       <td id="T_19dbc_row4_col4" class="data row4 col4" ><a href="https://platform.worldquantbrain.com/alpha/eOlZZmN">eOlZZmN</a></td>
#       <td id="T_19dbc_row4_col5" class="data row4 col5" ><a href="https://platform.worldquantbrain.com/alpha/EwZPjG1">EwZPjG1</a></td>
#       <td id="T_19dbc_row4_col6" class="data row4 col6" >ts_skewness(vec_avg(mws36_novelty),120)</td>
#       <td id="T_19dbc_row4_col7" class="data row4 col7" >group_rank(ts_skewness(vec_avg(mws36_novelty),120),sector)</td>
#     </tr>
#     <tr>
#       <th id="T_19dbc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_19dbc_row5_col0" class="data row5 col0" >0.210000</td>
#       <td id="T_19dbc_row5_col1" class="data row5 col1" >0.270000</td>
#       <td id="T_19dbc_row5_col2" class="data row5 col2" >0.290000</td>
#       <td id="T_19dbc_row5_col3" class="data row5 col3" >0.680000</td>
#       <td id="T_19dbc_row5_col4" class="data row5 col4" ><a href="https://platform.worldquantbrain.com/alpha/m8PWW39">m8PWW39</a></td>
#       <td id="T_19dbc_row5_col5" class="data row5 col5" ><a href="https://platform.worldquantbrain.com/alpha/LpPYvEe">LpPYvEe</a></td>
#       <td id="T_19dbc_row5_col6" class="data row5 col6" >ts_skewness(vec_avg(mws36_novelty_newest_span),120)</td>
#       <td id="T_19dbc_row5_col7" class="data row5 col7" >group_rank(ts_skewness(vec_avg(mws36_novelty_newest_span),120),sector)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Check merged alpha performance
#
# run the following code to do a before and after comparison of your merged pool post alpha submission

# %%
performance_comparison = ace.performance_comparison(s, result_st2['alpha_id'][0])

# %% [markdown]
# ### How to submit?
#
# Create a list of submittable alphas - alphas that have no FAIL in is_tests

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(new_result)
is_tests_df.head()
# Out:
#   alpha_id        date endDate  limit matched                 name result  \
# 0  Gwq52J5         NaN     NaN   1.58     NaN           LOW_SHARPE   FAIL
# 1  Gwq52J5         NaN     NaN   1.00     NaN          LOW_FITNESS   FAIL
# 2  Gwq52J5         NaN     NaN   0.01     NaN         LOW_TURNOVER   PASS
# 3  Gwq52J5         NaN     NaN   0.70     NaN        HIGH_TURNOVER   PASS
# 4  Gwq52J5  2017-02-22     NaN   0.10     NaN  CONCENTRATED_WEIGHT   FAIL
#
#   startDate themes unmatched     value  year
# 0       NaN    NaN       NaN  0.750000   NaN
# 1       NaN    NaN       NaN  0.320000   NaN
# 2       NaN    NaN       NaN  0.092800   NaN
# 3       NaN    NaN       NaN  0.092800   NaN
# 4       NaN    NaN       NaN  0.174242   NaN

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['Gwq52J5' '8zmx0AV' 'm8PWG26' 'Gwq52k0' 'EwZPjG1' 'LpPYvEe']
# Passed alphas:[]

# %% [markdown]
# When you got a list of submittable alphas, you can call function submit_alpha()

# %%
#calling submit_alpha on all alphas that have passed the submission tests

submit_result = {alpha_id: submit_alpha(s, alpha_id) for alpha_id in passed_alphas}

# %%
#submit_result will have return values from the submit_result function

submit_result
# Out:
# {}

# %% [markdown]
# ### Library Fuctions.
#
# following are some other functions that you can use for your own analysis
#
# **get_alpha_pnl(s, alpha_id)** - to get the pnl for an alpha
#
# **get_alpha_yearly_stats(s, alpha_id)** - to get yearly statistics for an alpha
#
# **get_self_corr(s, alpha_id)** - to get self correlation results for an alpha
#
# **get_prod_corr(s, alpha_id)** - to get prod correlation results for an alpha
#
# **get_check_submission(s, alpha_id)** - to get check submission result for an alpha
#
# **check_self_corr_test(s, alpha_id)** - to check if alpha passes self correlation test (self_corr<0.7)
#
# **check_prod_corr_test(s, alpha_id)** - to check if alpha passes prod correlation test (prod_corr<0.7)
#
# **perfomance_comparison(s, alpha_id)** - to get the result of performance comparison for an alpha merged performance
